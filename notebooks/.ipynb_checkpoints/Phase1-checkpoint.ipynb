# %% [markdown]
# # Anastomotic Leakage Prediction
# ### Phase 1 - Statistical Analysis

# %% [markdown]
# Taking the existing data manipulation and investigating:
# #### 1.1.
# * WRS, p value on the leakage vs not leakage for each existing attributes
# * Drop patients with missing value for the specific attribute in wrs
#
# #### 1.2.
# * If patients have no event data and have 0 on target, remove them
#
# #### 1.3.
# * Add categorical data and analyze correlation to target via hypergeometric
#
# #### 1.4.
# * Clear data by outlier detection. Look at the stf if its past 3std from the mean on both sides

# %%
import pandas as pd
import numpy as np
import re
import math
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
from datetime import datetime
from datetime import date 
from scipy import stats
import statsmodels.stats as ss 

import warnings
warnings.filterwarnings("ignore")

# %%
COMBINED_DATA_FILE = '../data_files/matrix0_missing_values.xlsx'
# EVENTS = '../data_files/data1.csv'
PATIENTS = '../data_files/anonymous_080620_DA_eg.xlsx' # Patient surgery data

full_df = pd.read_excel(COMBINED_DATA_FILE, header=[0,1,2,3])[1:]
# events_df = pd.read_csv(EVENTS)
patients_df = pd.read_excel(PATIENTS)

# %%
full_df
# Out:
#            type metadata                                       \
#            time  general
#         feature      Sex      Age   Urgency Surgical approach
#       statistic constant constant  constant          constant
# 1       1123813     male     59.0  elective              Open
# 2       1135541   female     43.0  elective              Open
# 3       3918745   female     57.0  elective      Laparoscopic
# 4       4894647      NaN      NaN  elective              Open
# 5       6541482   female     65.0    urgent              Open
# ..          ...      ...      ...       ...               ...
# 521  1031926105   female     63.0  elective              Open
# 522  1032366104   female     63.0  elective              Open
# 523  1033842103     male     61.0  elective              Open
# 524  1034462102     male     76.0  elective              Open
# 525  1035830101   female     65.0  elective              Open
#
#                      numeric_events                        ...                \
#                      before_surgery                        ... after_surgery
#     Anastomotic Leak        Albumin                        ...       weight
#             constant            max      mean median  min  ...          mean
# 1                1.0            4.2  4.200000   4.20  4.2  ...     96.966667
# 2                0.0            NaN       NaN    NaN  NaN  ...     68.000000
# 3                0.0            3.9  3.900000   3.90  3.9  ...           NaN
# 4                0.0            4.3  4.300000   4.30  4.3  ...     71.125000
# 5                0.0            3.1  1.942857   1.95  1.4  ...     54.666667
# ..               ...            ...       ...    ...  ...  ...           ...
# 521              0.0            NaN       NaN    NaN  NaN  ...           NaN
# 522              0.0            4.1  4.100000   4.10  4.1  ...     50.500000
# 523              1.0            4.8  4.800000   4.80  4.8  ...           NaN
# 524              0.0            4.3  4.300000   4.30  4.3  ...           NaN
# 525              0.0            3.7  3.700000   3.70  3.7  ...           NaN
#
#                      drugs                                     \
#                   all_days
#                  Cefazolin Ceftriaxone Fleet enema Furosemide
#     median   min     count       count       count      count
# 1    105.0  85.3       6.0        13.0         1.0       16.0
# 2     68.0  68.0       NaN        10.0         NaN        2.0
# 3      NaN   NaN       NaN         NaN         NaN        NaN
# 4     74.6   0.0       5.0        12.0         1.0       38.0
# 5     53.0  53.0       4.0        15.0         NaN      151.0
# ..     ...   ...       ...         ...         ...        ...
# 521    NaN   NaN       2.0         NaN         1.0        NaN
# 522   52.0  46.0       3.0         1.0         2.0        2.0
# 523    NaN   NaN       4.0        27.0         1.0        8.0
# 524    NaN   NaN       5.0         NaN         1.0        NaN
# 525    NaN   NaN       1.0         NaN         1.0        NaN
#
#
#
#     Magnesium sulfate Meroken new Metronidazole
#                 count       count         count
# 1                 4.0         1.0          52.0
# 2                 NaN         NaN          26.0
# 3                 NaN         NaN           NaN
# 4                 1.0         1.0          73.0
# 5                 7.0         NaN          51.0
# ..                ...         ...           ...
# 521               NaN         1.0           2.0
# 522              24.0         2.0           4.0
# 523              13.0         1.0          62.0
# 524               2.0         1.0           3.0
# 525               1.0         1.0           1.0
#
# [525 rows x 481 columns]

# %% [markdown]
# ### 1.1
# #### Feature Statistical Significance
# We will reconstruct the data to remove the large headers to it will be easier to manipulate and calculate the p_value of all features.
# We will maintain 3 dataframes:
# 1. patient_data
# 2. before_surgery_data
# 3. after_surgery_data
#
# For dataframes with median, mean, max, min we will take the $mean$ value

# %%
# Group One - Group of the patient and surgery attributes
group_one = full_df.iloc[:, 0:6]
group_one.columns = full_df.columns.get_level_values(2)[0:6]
# group_one

# Group Two - Group of the event attributes
group_two = full_df.iloc[:,6:-7]
group_two = group_two.iloc[:, 1::4]  # 4 = Taking the mean from each features
group_two.columns = group_two.columns.get_level_values(2)

# %%
# Concatenating the two lists (easier to do this because of hierarchical headers)
raw_data = pd.concat([group_one, group_two], axis=1, sort=False)

# %%
# This data set has all data with smaller header
raw_data.rename(columns={'feature': 'ID'}, inplace=True)
raw_data
# Out:
#              ID     Sex   Age   Urgency Surgical approach  Anastomotic Leak  \
# 1       1123813    male  59.0  elective              Open               1.0
# 2       1135541  female  43.0  elective              Open               0.0
# 3       3918745  female  57.0  elective      Laparoscopic               0.0
# 4       4894647     NaN   NaN  elective              Open               0.0
# 5       6541482  female  65.0    urgent              Open               0.0
# ..          ...     ...   ...       ...               ...               ...
# 521  1031926105  female  63.0  elective              Open               0.0
# 522  1032366104  female  63.0  elective              Open               0.0
# 523  1033842103    male  61.0  elective              Open               1.0
# 524  1034462102    male  76.0  elective              Open               0.0
# 525  1035830101  female  65.0  elective              Open               0.0
#
#       Albumin  Alkaline Phosphatase    Amylase  BASO (%)  ...      WBC_1  \
# 1    4.200000                  97.0  63.000000  0.500000  ...   7.262093
# 2         NaN                   NaN        NaN       NaN  ...  11.480556
# 3    3.900000                  90.0  53.000000  0.400000  ...  11.616000
# 4    4.300000                  70.0        NaN  0.300000  ...   5.549455
# 5    1.942857                  94.0  32.692308  0.121429  ...  13.174151
# ..        ...                   ...        ...       ...  ...        ...
# 521       NaN                   NaN        NaN       NaN  ...   5.947778
# 522  4.100000                 133.0  78.000000  0.600000  ...   4.561719
# 523  4.800000                  89.0  19.000000  0.300000  ...   9.365849
# 524  4.300000                  92.0  95.000000  0.500000  ...   5.274000
# 525  3.700000                 101.0  40.000000  0.400000  ...   9.785455
#
#      blood pressure  blood pressure diastolic   blood pressure systolic  \
# 1         89.676093                  64.431373               120.596026
# 2         90.180000                  51.000000                97.000000
# 3        115.000000                  75.357143               126.851852
# 4         89.430524                  63.564885               114.832000
# 5         99.845560                  76.267176               128.078740
# ..              ...                        ...                      ...
# 521      106.214286                  67.270588               121.282353
# 522      102.408163                  64.205357               119.700000
# 523       98.692230                  71.186441               129.844828
# 524      121.948276                  58.076923               118.947368
# 525       94.272727                  64.230769               110.555556
#
#      body temperature  heart rate      height  respiratory rate, CO2  \
# 1           36.609656   87.566667  174.000000               9.800000
# 2           36.745455   87.760000  170.000000               6.647059
# 3           35.727778   73.147059         NaN               4.684211
# 4           36.658712   86.694690  168.583333               6.585366
# 5           36.910182   89.780980  150.000000               8.125000
# ..                ...         ...         ...                    ...
# 521         36.652381  100.649254         NaN               9.593750
# 522         36.592308   87.720548  151.285714               5.288136
# 523         37.121285   87.518519         NaN              11.107143
# 524         36.175000   74.742424         NaN              11.916667
# 525         36.853333   93.605839         NaN               8.758621
#
#      saturation    weight
# 1     97.169284  96.966667
# 2     97.927711  68.000000
# 3     96.787879        NaN
# 4     96.739583  71.125000
# 5     97.231970  54.666667
# ..          ...        ...
# 521   97.245455        NaN
# 522   97.741935  50.500000
# 523   96.892694        NaN
# 524   97.530303        NaN
# 525   97.781818        NaN
#
# [525 rows x 123 columns]

# %%
patients_df = patients_df.drop_duplicates() # Removed ~150 duplicates

# %%
# Attempted to add surgery name/area but there is an issue with the dates of each surgery. 

# Taking only relevant columns
patient_extra_data = pd.concat([patients_df.iloc[:,0:1], patients_df.iloc[:,-10:-9], patients_df.iloc[:,-9:-7]], axis=1, sort=False)
# Taking only patients that have more than one surgery, 36 patients
duplicate_sugeries_patients = patient_extra_data['Code'].value_counts().to_frame().iloc[:36,:].reset_index()
# Look at the entire row for these patients with many surgeries
temp = patient_extra_data.merge(duplicate_sugeries_patients,right_on="index", left_on="Code", how='inner')
temp.iloc[:50,:-2]
# Out:
#         Code_x Surgery Date Patient Classification  \
# 0    111570821   2018-06-07      Surgical Oncology
# 1    111570821   2018-05-06      Surgical Oncology
# 2    110558531   2018-06-02      Surgical Oncology
# 3    110558531   2018-05-30      Surgical Oncology
# 4    110558531   2018-12-10             Colorectal
# 5    109193045   2018-07-16      Surgical Oncology
# 6    109193045   2018-05-15           Appendectomy
# 7     10887548   2018-05-28      Surgical Oncology
# 8     10887548   2018-11-14      Surgical Oncology
# 9     10887548   2018-12-10      Surgical Oncology
# 10   107726459   2018-05-09      Surgical Oncology
# 11   107726459   2018-09-12      Surgical Oncology
# 12  1030904106   2018-04-13      Surgical Oncology
# 13  1030904106   2018-01-24      Surgical Oncology
# 14  1027149109   2018-04-24      Surgical Oncology
# 15  1027149109   2018-01-08      Surgical Oncology
# 16  1026431110   2018-04-25      Surgical Oncology
# 17  1026431110   2018-12-23      Surgical Oncology
# 18  1022534114   2018-01-23      Surgical Oncology
# 19  1022534114   2018-11-25             Colorectal
# 20  1007828129   2018-02-11      Surgical Oncology
# 21  1007828129   2018-02-11             Colorectal
# 22   995820141   2018-11-06      Surgical Oncology
# 23   995820141   2018-12-19      Surgical Oncology
# 24   984332152   2018-11-13      Surgical Oncology
CLOSURE OF ILEOSTOMY, WITH SMALL TO LARGE ANAS...
# 37  CLOSURE OF ILEOSTOMY, WITH SMALL TO SMALL ANAS...
# 38  EXPLORATORY LAPAROTOMY 490000;OPEN ILEOSTOMY O...
# 39  DIAGNOSTIC/ STAGING LAPAROSCOPY 493200; EXPLOR...
# 40  EXPLORATORY LAPAROTOMY 490000; OPEN SMALL BOWE...
# 41  EXPLORATORY LAPAROTOMY 490000; OPEN ILEOSTOMY ...
# 42  LAPAROSCOPIC INCARCERATED EPIGASTRIC HERNIA RE...
# 43  LAPAROSCPIC SLEEVEGASTRECTOMY WITH DIADIAPHRAG...
# 44                      EXPLORATORY LAPAROTOMY 490000
# 45               LAPAROSCOPIC RIGHT HEMICOLECTOMY 302
# 46  DIAGNOSTIC LAPAROSCOPY 493200;OPEN DRAINAGE OF...
# 47  CLOSURE OF ILEOSTOMY, WITH SMALL TO LARGE ANAS...
# 48  OPEN ANTERIOR RESECTION OF RECTUM 264;OPEN SIG...
# 49  CLOSURE OF ILEOSTOMY, WITH SMALL TO SMALL ANAS...

# %%
# Remove single instance with robotic surgery (AL = 0)
raw_data = raw_data[raw_data['Surgical approach'] != 'Robotic Surgery']

# %% [markdown]
# We will not fill p_value data for each attribute, for the first 4 categorical features we will aquire the p-value from Fisher's exact test (https://en.wikipedia.org/wiki/Fisher%27s_exact_test)  while for the remaining numerical features we will use WRS

# %%
# Initializing Dataframes

patient_data = pd.DataFrame(raw_data.iloc[:,1:6])
before_surgery_data = pd.DataFrame(raw_data.iloc[:,5:59])
after_surgery_data = pd.DataFrame(pd.concat([raw_data[['Anastomotic Leak']],raw_data.iloc[:,59:]],axis =1))
stats_patient_data = pd.DataFrame(columns = patient_data.columns ,index=['p_val','cv'])
stats_before_surgery_data = pd.DataFrame(columns=before_surgery_data.columns, index = ['p_val','cv'])
stats_after_surgery_data = pd.DataFrame(columns=after_surgery_data.columns, index = ['p_val','cv'])

# %%
# Constructing delta between before and after surgery
common_columns = set(before_surgery_data.columns).intersection(after_surgery_data)
delta = pd.DataFrame(columns = common_columns)
delta.drop('Anastomotic Leak', inplace=True, axis=1)
stats_surgery_data_delta = pd.DataFrame(columns=delta.columns, index = ['p_val','cv'])

# Populating delta df
for i in delta.columns:
    # After Surgery - Before Surgery
    delta[i] = after_surgery_data[i] - before_surgery_data[i]

# %% [markdown]
# ##### 1.1.1 The Wilcoxon Rank Sum and Coefficient of Variation

# %%
# 2x2 matrix  class1 class 2
#   feature1     []  []
#   feature2     []  []

def catagorical_count_matrix (feature):
    mat = []
    for i in range(raw_data[feature].value_counts().size):
        try: a = raw_data[raw_data['Anastomotic Leak'] == 1][feature].value_counts()[i]
        except: a = 0
        try: b = raw_data[raw_data['Anastomotic Leak'] == 0][feature].value_counts()[i]
        except: b = 0
        a = [a,b]
        mat.append(a)
    return list(mat)

def calc_wrs(f):
    ## defining the two independent samples
    a = f[raw_data['Anastomotic Leak'] == 0.0].dropna()
    b = f[raw_data['Anastomotic Leak'] == 1.0].dropna()
    return stats.ranksums(a,b)

# %%
def get_pval_cv (original_df, stats_df):
# Allocating patient data p_val
    for i in zip(original_df.columns, original_df.dtypes):
        if i[1] == 'object':
            # Calcuating P_Val - catagorically with fisher's exact test
            stats_df[i[0]][0] = stats.fisher_exact(catagorical_count_matrix(i[0]))[1]
        else:
            # Calcuating P_Val - catagorically with WRS
            stats_df[i[0]][0] = calc_wrs(original_df[i[0]])[1]
            # Getting the CV - Coefficient of Variation
            stats_df[i[0]][1] = np.std(original_df[i[0]])/np.mean(original_df[i[0]])
    return

# %%
def plot_1row (df ,title, type):
    plt.figure(figsize=(20,20))
    if (type == 'neg log'):
        # Log based e (NL)
        ax = sns.barplot(-np.log(df.values.reshape(-1,).tolist()), df.columns)
    else:
        ax = sns.barplot((df.values.reshape(-1,).tolist()), df.columns)
    ax.set_title(title, size=20)
    for p in ax.patches:
        width = p.get_width() # bar length
        ax.text(width * 0.5, p.get_y() + p.get_height() / 2, '{:1.2f}'.format(width),  
                ha = 'center', va = 'center', size=13)
    plt.show()

# %%
get_pval_cv(patient_data,stats_patient_data)
get_pval_cv(before_surgery_data,stats_before_surgery_data)
get_pval_cv(after_surgery_data,stats_after_surgery_data)
get_pval_cv(delta, stats_surgery_data_delta)

# %% [markdown]
# ##### Plotting P_Vals

# %%
plot_1row(stats_patient_data.iloc[:1,:-1],"Surgery and Patient Data - NegativeLog(pvalue) ", 'neg log')

# %%
plot_1row(stats_before_surgery_data.iloc[:-1,1:],"Before Surgery - NegativeLog(pvalue) ", 'neg log')

# %%
plot_1row(stats_after_surgery_data.iloc[:-1,1:],"After Surgery - NegativeLog(pvalue) ", 'neg log')

# %%
plot_1row(stats_surgery_data_delta.iloc[:-1,1:],"Surgery Delta - NegativeLog(pvalue) ", 'neg log')

# %% [markdown]
# ##### 1.1.2. Disjointification
# Ranking the features by the wrs, then take the highest, then take the correlation between the k-th and k-1 and then remove the bottom one if a correlation appears

# %%
def get_disjointification_value(df, stats_df):
    if "Anastomotic Leak" in df.columns:
        sorted_df = stats_df.sort_values(by ='p_val', axis=1).drop("Anastomotic Leak",axis = 1)
    else:
        sorted_df = stats_df.sort_values(by ='p_val', axis=1)
    results = pd.DataFrame()
    for i in range(sorted_df.shape[1]):
        features = []
        # get the list of higher p-value'd features
        for j in range(i,0,-1):
            features.append(sorted_df.iloc[:,j].name)
        # compare their pearsons
        for comp_feature in features[1:]:
            temp = pd.DataFrame((df[features[0]], df[comp_feature])).T
            temp.dropna(axis=0, how = 'any',inplace=True)   
            pearson = stats.pearsonr(temp.iloc[:,0], temp.iloc[:,1])[0]
            if np.absolute(pearson) > 0.5:
                print("{} | {} - REMOVE".format(features[0],comp_feature),pearson)
            else:
                print("{} | {}".format(features[0],comp_feature),pearson)

# %%
dj_before_surgery = get_disjointification_value(before_surgery_data, stats_before_surgery_data)
# dj_after_surgery = get_disjointification_value(after_surgery_data, stats_after_surgery_data)
# dj_delta = get_disjointification_value(delta, stats_surgery_data_delta)
# Out:
# RBC | HCT - REMOVE 0.8741512264461252
# HGB | RBC - REMOVE 0.8294089057963633
# HGB | HCT - REMOVE 0.9841124958724328
# Protein, total | HGB - REMOVE 0.5576034250630854
# Protein, total | RBC - REMOVE 0.5566395804203692
# Protein, total | HCT - REMOVE 0.572920817987483
# LYMPHO (abs) | Protein, total 0.43639611027983477
# LYMPHO (abs) | HGB 0.4008939629883204
# LYMPHO (abs) | RBC 0.3892828572623773
# LYMPHO (abs) | HCT 0.4227926449991119
# weight  | LYMPHO (abs) 0.22383597244094336
# weight  | Protein, total 0.1664212234203148
# weight  | HGB 0.20633734703754095
# weight  | RBC 0.23934080786275003
# weight  | HCT 0.2129056443821205
# Albumin | weight  0.14891478218942222
# Albumin | LYMPHO (abs) 0.43103545073896676
# Albumin | Protein, total - REMOVE 0.8556977517247076
# Albumin | HGB - REMOVE 0.6380547700262271
# Albumin | RBC - REMOVE 0.5805852906069093
# Albumin | HCT - REMOVE 0.6423100516090308
# LYMPHO (%) | Albumin 0.45254575525747476
# LYMPHO (%) | weight  0.10762246533301206
# LYMPHO (%) | LYMPHO (abs) - REMOVE 0.7286920159536675
# LYMPHO (%) | Protein, total 0.3865497724784604
# LYMPHO (%) | HGB 0.3438821964680151
# LYMPHO (%) | RBC 0.2859763350759036
# LYMPHO (%) | HCT 0.35188424565528476
# NEUTRO (%) | LYMPHO (%) - REMOVE -0.9556566907941528
# NEUTRO (%) | Albumin -0.3981605631539936
# NEUTRO (%) | weight  -0.08132751327542653
# NEUTRO (%) | LYMPHO (abs) - REMOVE -0.6434417550934834
# NEUTRO (%) | Protein, total -0.34054048935111547
# NEUTRO (%) | HGB -0.2977303250066873
# NEUTRO (%) | RBC -0.23785453969987042
# NEUTRO (%) | HCT -0.3022365122515921
# Estimated Globulin | NEUTRO (%) -0.08230775625375217
# Estimated Globulin | LYMPHO (%) 0.09246799226475735
# Estimated Globulin | Albumin 0.19811284753592714
# Estimated Globulin | weight  0.09709142934349915
# Estimated Globulin | LYMPHO (abs) 0.21911910486741468
# Estimated Globulin | Protein, total - REMOVE 0.6737587580605977
# Estimated Globulin | HGB 0.14495842951880394
# Estimated Globulin | RBC 0.2265240501741702
# Estimated Globulin | HCT 0.1694931781287824
# Amylase | Estimated Globulin 0.04126431947959683
# Amylase | NEUTRO (%) 0.08157268359973177
# Amylase | LYMPHO (%) -0.06919452815369892
# Amylase | Albumin 0.07391953986042958
# Amylase | weight  -0.13027549564887209
# Amylase | LYMPHO (abs) -0.11378116614062171
# Amylase | Protein, total 0.08089291853493716
# Amylase | HGB 0.011086235445090159
# Amylase | RBC -0.05162710933031346
# Amylase | HCT -0.008249288440831887
# Bilirubin, direct | Amylase 0.027677348262214647
# Bilirubin, direct | Estimated Globulin -0.13023032766457188
# Bilirubin, direct | NEUTRO (%) 0.08912192745470807
# Bilirubin, direct | LYMPHO (%) -0.1426113799930248
# Bilirubin, direct | Albumin -0.20908666485883187
# Bilirubin, direct | weight  -0.042771316277573135
# Bilirubin, direct | LYMPHO (abs) -0.1688593974193196
# Bilirubin, direct | Protein, total -0.21825821072203738
# Bilirubin, direct | HGB -0.08060827487335813
# Bilirubin, direct | RBC -0.10682885567663522
# Bilirubin, direct | HCT -0.10636019877600386
# Phosphorus | Bilirubin, direct -0.1334879158355528
# Phosphorus | Amylase -0.010643433319036315
# Phosphorus | Estimated Globulin 0.1154430411403207
# Phosphorus | NEUTRO (%) -0.1396491345507637
# Phosphorus | LYMPHO (%) 0.16540505671523378
# Phosphorus | Albumin 0.18206123578546746
# Phosphorus | weight  0.0801896820533319
# Phosphorus | LYMPHO (abs) 0.15747744683850246
# Phosphorus | Protein, total 0.19777229565403062
# Phosphorus | HGB 0.06966998134434596
# Phosphorus | RBC 0.15338657915885445
# Phosphorus | HCT 0.09290546772159466
# Chloride | Phosphorus -0.17146638977721795
# Chloride | Bilirubin, direct -0.09392408321904502
# Chloride | Amylase 0.07621508848265243
# Chloride | Estimated Globulin -0.2880209797596712
# Chloride | NEUTRO (%) -0.06592055324886388
# Chloride | LYMPHO (%) 0.051890917371270835
# Chloride | Albumin -0.08416110929860465
# Chloride | weight  -0.0454522378368538
# Chloride | LYMPHO (abs) -0.043816048349604314
# Chloride | Protein, total -0.2176476528654251
# Chloride | HGB -0.15864764678253376
# Chloride | RBC -0.20013024130627483
# Chloride | HCT -0.18321642512082845
# Calcium, total | Chloride -0.1342059930347942
# Calcium, total | Phosphorus 0.1926115962484839
# Calcium, total | Bilirubin, direct -0.17374434018160606
# Calcium, total | Amylase 0.06148121866309757
# Calcium, total | Estimated Globulin 0.27457021708944734
# Calcium, total | NEUTRO (%) -0.3439505270394718
# Calcium, total | LYMPHO (%) 0.377457374652832
# Calcium, total | Albumin - REMOVE 0.7637863869898514
# Calcium, total | weight  0.09012324543265754
# Calcium, total | LYMPHO (abs) 0.3636483700864985
# Calcium, total | Protein, total - REMOVE 0.7154527753582376
# Calcium, total | HGB 0.48991945063388237
# Calcium, total | RBC 0.46723757553243483
# Calcium, total | HCT - REMOVE 0.511434429000571
# body temperature | Calcium, total 0.023753334092117294
# body temperature | Chloride -0.08354662672592791
# body temperature | Phosphorus 0.06175698307389403
# body temperature | Bilirubin, direct 0.01239962827614231
# body temperature | Amylase -0.08050782053396174
# body temperature | Estimated Globulin 0.14536878616157917
# body temperature | NEUTRO (%) -0.10785007844938592
# body temperature | LYMPHO (%) 0.092832787951016
# body temperature | Albumin 0.040320911905086784
# body temperature | weight  -0.024721862665436314
# body temperature | LYMPHO (abs) 0.0791560000698652
# body temperature | Protein, total 0.10202200757483389
# body temperature | HGB -0.05501803273448384
# body temperature | RBC 0.025147614047361308
# body temperature | HCT -0.05007945696971556
# NEUTRO (abs) | body temperature -0.11063469462391913
# NEUTRO (abs) | Calcium, total -0.2096732251530256
# NEUTRO (abs) | Chloride -0.16575353733095313
# NEUTRO (abs) | Phosphorus -0.07849748821521474
# NEUTRO (abs) | Bilirubin, direct 0.03612127744001221
# NEUTRO (abs) | Amylase 0.06518003858067418
# NEUTRO (abs) | Estimated Globulin 0.019856939897285125
# NEUTRO (abs) | NEUTRO (%) - REMOVE 0.6789402714127413
# NEUTRO (abs) | LYMPHO (%) - REMOVE -0.6058609476160186
# NEUTRO (abs) | Albumin -0.26439798146213594
# NEUTRO (abs) | weight  0.034295497663538815
# NEUTRO (abs) | LYMPHO (abs) -0.04564763529449177
# NEUTRO (abs) | Protein, total -0.19015854869480597
# NEUTRO (abs) | HGB -0.1183269694909118
# NEUTRO (abs) | RBC -0.041965259714007996
# NEUTRO (abs) | HCT -0.10799669813209956
# INR | NEUTRO (abs) 0.10793702407710808
# INR | body temperature 0.13995884276312218
# INR | Calcium, total -0.29222054114678475
# INR | Chloride -0.07392619112574214
# INR | Phosphorus 0.01981259721780865
# INR | Bilirubin, direct 0.11169150971132039
# INR | Amylase 0.0623624128530268
# INR | Estimated Globulin 0.03613734100315402
# INR | NEUTRO (%) 0.23227161833969023
# INR | LYMPHO (%) -0.26899793116405524
# INR | Albumin -0.4266169722010533
# INR | weight  -0.06215646767701589
# INR | LYMPHO (abs) -0.2517343765172965
# INR | Protein, total -0.2974026632355278
# INR | HGB -0.2022911434344183
# INR | RBC -0.14337198997528747
# INR | HCT -0.19759207100352516
# heart rate | INR 0.1584886614332608
# heart rate | NEUTRO (abs) 0.22489844954940538
# heart rate | body temperature 0.10542458536430271
# heart rate | Calcium, total -0.184885077459561
# heart rate | Chloride -0.1984426361895847
# heart rate | Phosphorus 0.043214228435758305
# heart rate | Bilirubin, direct 0.043058029747313174
# heart rate | Amylase -0.041646117617439304
# heart rate | Estimated Globulin 0.11026824847982768
# heart rate | NEUTRO (%) 0.18144842857789284
# heart rate | LYMPHO (%) -0.1734938249356213
# heart rate | Albumin -0.1734109659965679
# heart rate | weight  0.01436230955930528
# heart rate | LYMPHO (abs) -0.04194868198091824
# heart rate | Protein, total -0.07056568431509
# heart rate | HGB -0.06927339410877349
# heart rate | RBC 0.013419984616819106
# heart rate | HCT -0.066183317873592
# PT | heart rate -0.20787472850502986
# PT | INR - REMOVE -0.8319128580548202
# PT | NEUTRO (abs) -0.19138152418771937
# PT | body temperature -0.06191095029559923
# PT | Calcium, total 0.3553744561329907
# PT | Chloride 0.05490861244200643
# PT | Phosphorus 0.06658671177995212
# PT | Bilirubin, direct -0.10837766418292327
# PT | Amylase 0.01892581674644239
# PT | Estimated Globulin 0.04068218554368577
# PT | NEUTRO (%) -0.3448941990578111
# PT | LYMPHO (%) 0.38225390641071344
# PT | Albumin 0.48327591470027526
# PT | weight  0.05041722512417472
# PT | LYMPHO (abs) 0.3486835224039746
# PT | Protein, total 0.37938588720346944
# PT | HGB 0.27028181818673036
# PT | RBC 0.19963773093604845
# PT | HCT 0.2652664357519072
# Urea | PT -0.20050809649728507
# Urea | heart rate -0.029119448141084546
# Urea | INR 0.3243209038213495
# Urea | NEUTRO (abs) 0.11651754790434236
# Urea | body temperature 0.021867829204419473
# Urea | Calcium, total -0.10580199529451279
# Urea | Chloride 0.007937249517595779
# Urea | Phosphorus 0.1865891785415698
# Urea | Bilirubin, direct 0.09953162500203051
# Urea | Amylase 0.20862125989370933
# Urea | Estimated Globulin 0.004209876904538799
# Urea | NEUTRO (%) 0.21293465164153963
# Urea | LYMPHO (%) -0.2342478025168458
# Urea | Albumin -0.28039916143518046
# Urea | weight  -0.04007071156099101
# Urea | LYMPHO (abs) -0.23066203582012867
# Urea | Protein, total -0.21194865591342302
# Urea | HGB -0.1725898765233564
# Urea | RBC -0.18527690279100306
# Urea | HCT -0.17315641825520975
# blood pressure | Urea -0.04424920320806395
# blood pressure | PT 0.21577609570894354
# blood pressure | heart rate -0.01597535428064289
# blood pressure | INR -0.21291493388036828
# blood pressure | NEUTRO (abs) 0.03075023504177945
# blood pressure | body temperature -0.02144964142804992
# blood pressure | Calcium, total 0.32928159817920166
# blood pressure | Chloride -0.09816708103087265
# blood pressure | Phosphorus 0.031207790074131526
# blood pressure | Bilirubin, direct -0.08070266977270107
# blood pressure | Amylase 0.013532144579030968
# blood pressure | Estimated Globulin 0.11642669339415629
# blood pressure | NEUTRO (%) -0.1151562019178879
# blood pressure | LYMPHO (%) 0.1420129252355064
# blood pressure | Albumin 0.3574506489149456
# blood pressure | weight  0.21002762236513878
# blood pressure | LYMPHO (abs) 0.23668479086358368
# blood pressure | Protein, total 0.3287653419996968
# blood pressure | HGB 0.36063778715603034
# blood pressure | RBC 0.3865060960109338
# blood pressure | HCT 0.3762043224182815
# EOS (abs) | blood pressure 0.065573199322078
# EOS (abs) | Urea -0.1199795978849987
# EOS (abs) | PT 0.16578150451421303
# EOS (abs) | heart rate -0.023650358521090282
# EOS (abs) | INR -0.1530015510632673
# EOS (abs) | NEUTRO (abs) -0.08382530351865901
# EOS (abs) | body temperature 0.08556851629198736
# EOS (abs) | Calcium, total 0.12273780533110584
# EOS (abs) | Chloride 0.06588871635389959
# EOS (abs) | Phosphorus 0.05006148819499465
# EOS (abs) | Bilirubin, direct -0.06916255280368486
# EOS (abs) | Amylase -0.06274523447644999
# EOS (abs) | Estimated Globulin 0.1339229461816171
# EOS (abs) | NEUTRO (%) -0.30498803087629295
# EOS (abs) | LYMPHO (%) 0.20729275901681163
# EOS (abs) | Albumin 0.13178884873488525
# EOS (abs) | weight  0.10844049375589046
# EOS (abs) | LYMPHO (abs) 0.3667994624662803
# EOS (abs) | Protein, total 0.1710623088726359
# EOS (abs) | HGB 0.12291773936185046
# EOS (abs) | RBC 0.13424756625158324
# EOS (abs) | HCT 0.13032266378227894
# SGOT (AST) | EOS (abs) -0.05327855583542015
# SGOT (AST) | blood pressure -0.05991025764905223
# SGOT (AST) | Urea 0.0733974275438912
# SGOT (AST) | PT -0.06732493921290578
# SGOT (AST) | heart rate 0.08924018640999945
# SGOT (AST) | INR 0.035379067749087625
# SGOT (AST) | NEUTRO (abs) 0.07976421020635796
# SGOT (AST) | body temperature -0.035260616336725
# SGOT (AST) | Calcium, total -0.1978454525236717
# SGOT (AST) | Chloride -0.10295585384721458
# SGOT (AST) | Phosphorus 0.006580576849502036
# SGOT (AST) | Bilirubin, direct - REMOVE 0.5913571760389731
# SGOT (AST) | Amylase 0.14163946179177428
# SGOT (AST) | Estimated Globulin -0.07877456700890635
# SGOT (AST) | NEUTRO (%) 0.08492015138716331
# SGOT (AST) | LYMPHO (%) -0.109775093162056
# SGOT (AST) | Albumin -0.15419239984989624
# SGOT (AST) | weight  -0.05838420284026574
# SGOT (AST) | LYMPHO (abs) -0.10399392751099606
# SGOT (AST) | Protein, total -0.1562643037553338
# SGOT (AST) | HGB -0.06935718060224788
# SGOT (AST) | RBC -0.10333507954485241
# SGOT (AST) | HCT -0.08461501551084041
# EOS (%) | SGOT (AST) -0.05212278351019378
# EOS (%) | EOS (abs) - REMOVE 0.9071022686757187
# EOS (%) | blood pressure -0.01811313195814298
# EOS (%) | Urea -0.13026865155682638
# EOS (%) | PT 0.16410987628629917
# EOS (%) | heart rate -0.06611307866512514
# EOS (%) | INR -0.15198515075730964
# EOS (%) | NEUTRO (abs) -0.3103711159193837
# EOS (%) | body temperature 0.09815263372348809
# EOS (%) | Calcium, total 0.11547708450180544
# EOS (%) | Chloride 0.1220958666511069
# EOS (%) | Phosphorus 0.011841346390393588
# EOS (%) | Bilirubin, direct -0.0525180306886614
# EOS (%) | Amylase -0.03660423989400738
# EOS (%) | Estimated Globulin 0.07390116649645241
# EOS (%) | NEUTRO (%) -0.3557751348905644
# EOS (%) | LYMPHO (%) 0.22266002767294613
# EOS (%) | Albumin 0.11054762865168051
# EOS (%) | weight  0.03903097997122108
# EOS (%) | LYMPHO (abs) 0.1685693335800467
# EOS (%) | Protein, total 0.12423002161478514
# EOS (%) | HGB 0.06677561443965184
# EOS (%) | RBC 0.06550440497558385
# EOS (%) | HCT 0.06816273451980955
# PTT | EOS (%) -0.04189850623105863
# PTT | SGOT (AST) -0.03821490494028107
# PTT | EOS (abs) -0.03901124264053145
# PTT | blood pressure 0.06767311667921456
# PTT | Urea 0.11962353960824748
# PTT | PT -0.19745982838915738
# PTT | heart rate -0.060290998553427844
# PTT | INR 0.3118550261630936
# PTT | NEUTRO (abs) -0.08919041360285715
# PTT | body temperature 0.122124306117735
# PTT | Calcium, total 0.09690467780241441
# PTT | Chloride 0.05089838955200075
# PTT | Phosphorus 0.08993088338145178
# PTT | Bilirubin, direct 0.04476207017370803
# PTT | Amylase 0.014501739129638407
# PTT | Estimated Globulin 0.07536096678322919
# PTT | NEUTRO (%) -0.0485947782930965
# PTT | LYMPHO (%) 0.06101758469555915
# PTT | Albumin 0.055543088317685084
# PTT | weight  -0.03145143630785
# PTT | LYMPHO (abs) 0.03377637590009744
# PTT | Protein, total 0.07764951260019713
# PTT | HGB 0.06645736087558535
# PTT | RBC 0.03140651591772679
# PTT | HCT 0.0736157414851907
# Glucose | PTT -0.13939141422979884
# Glucose | EOS (%) -0.08665268405245957
# Glucose | SGOT (AST) 0.0008786534657087824
# Glucose | EOS (abs) -0.053033686529639495
# Glucose | blood pressure 0.016403669724719593
# Glucose | Urea 0.31426233628756245
# Glucose | PT -0.13005644831815488
# Glucose | heart rate 0.16079828533896529
# Glucose | INR 0.11504830504572655
# Glucose | NEUTRO (abs) 0.24126017904749258
# Sodium | EOS (abs) 0.11017815597685444
# Sodium | blood pressure 0.047551356481444346
# Sodium | Urea -0.0096777914208383
# Sodium | PT 0.12195834498354663
# Sodium | heart rate -0.2143507050069559
# Sodium | INR -0.15061821297479117
# Sodium | NEUTRO (abs) -0.13250091875406808
# Sodium | body temperature -0.045417137931431324
# Sodium | Calcium, total 0.15809208438386121
# Sodium | Chloride - REMOVE 0.6472673250056352
# Sodium | Phosphorus -0.014427479604987409
# Sodium | Bilirubin, direct -0.14222054062568312
# Sodium | Amylase -0.03391076843204674
# Sodium | Estimated Globulin -0.1015201846110928
# Sodium | NEUTRO (%) -0.12668899971129927
# Sodium | LYMPHO (%) 0.10530112586919134
# Sodium | Albumin 0.17056572284461868
# Sodium | weight  -0.004010248000771331
# Sodium | LYMPHO (abs) 0.0766146151485442
# Sodium | Protein, total 0.06749383912011883
# Sodium | HGB 0.05592041628701171
# Sodium | RBC -0.006938513601118974
# Sodium | HCT 0.04195975185229201
# BASO (%) | Sodium 0.04778831731566956
# BASO (%) | MCHC 0.0547782135864633
# BASO (%) | RDW -0.10087464680905729
# BASO (%) | Alkaline Phosphatase -0.017272370021387047
# BASO (%) | Bilirubin, total -0.05507120019427489
# BASO (%) | Creatinine -0.13336545007863723
# BASO (%) | height -0.048499121957434874
# BASO (%) | Glucose -0.13657488160996567
# BASO (%) | PTT -0.005436961394695447
# BASO (%) | EOS (%) 0.2429849240751047
# BASO (%) | SGOT (AST) 0.013583650559010821
# BASO (%) | EOS (abs) 0.20437366058178835
# BASO (%) | blood pressure 0.09721672325211594
# BASO (%) | Urea -0.20411673747356365
# BASO (%) | PT 0.15426400995425327
# BASO (%) | heart rate -0.10990416439293475
# BASO (%) | INR -0.12087542400629453
# BASO (%) | NEUTRO (abs) -0.30528204831449507
# BASO (%) | body temperature 0.02766292843028413
# BASO (%) | Calcium, total 0.21154535277269787
# BASO (%) | Chloride 0.035139955865160236
# BASO (%) | Phosphorus -0.030906736592239033
# BASO (%) | Bilirubin, direct -0.013965462799451663
# BASO (%) | Amylase -0.05217584487135564
# BASO (%) | Estimated Globulin 0.1664876550596569
# BASO (%) | NEUTRO (%) -0.38352875805196357
# BASO (%) | LYMPHO (%) 0.33234662303515183
# BASO (%) | Albumin 0.21486805578868362
# BASO (%) | weight  0.005742979449634908
# BASO (%) | LYMPHO (abs) 0.24981611224233088
# BASO (%) | Protein, total 0.24955496602995636
# BASO (%) | HGB 0.0930137823368861
# BASO (%) | RBC 0.075079056275342
# BASO (%) | HCT 0.09021515729990355
# WBC_1 | BASO (%) -0.2016844657261763
# WBC_1 | Sodium -0.09623323682569182
# WBC_1 | MCHC -0.12582735708658885
# WBC_1 | RDW -0.02003371452910267
# WBC_1 | Alkaline Phosphatase -0.04304195841368203
# WBC_1 | Bilirubin, total 0.0034248046347681513
# WBC_1 | Creatinine 0.07814788856548013
# WBC_1 | height -0.059919501286707866
# WBC_1 | Glucose 0.1912558762204723
# WBC_1 | PTT -0.08682320270237737
# WBC_1 | EOS (%) -0.20923274152311166
# WBC_1 | SGOT (AST) 0.06461889991676852
# WBC_1 | EOS (abs) 0.06964218160736942
# WBC_1 | blood pressure 0.10261762154705882
# WBC_1 | Urea 0.05328137078942789
# WBC_1 | PT -0.0847160606116085
# WBC_1 | heart rate 0.19785913601267935
# WBC_1 | INR 0.03164604513448963
# WBC_1 | NEUTRO (abs) - REMOVE 0.9451962310095448
# WBC_1 | body temperature -0.08110453413583496
# WBC_1 | Calcium, total -0.10532336618567452
# WBC_1 | Chloride -0.16408527262310077
# WBC_1 | Phosphorus -0.03141085262844331
# WBC_1 | Bilirubin, direct -0.0015819344511374261
# WBC_1 | Amylase 0.01955011121983747
# WBC_1 | Estimated Globulin 0.07881580972070018
# WBC_1 | NEUTRO (%) 0.4391554759144741
# WBC_1 | LYMPHO (%) -0.3644978626138416
# WBC_1 | Albumin -0.15108028982841532
# WBC_1 | weight  0.09104027629707427
# WBC_1 | LYMPHO (abs) 0.255915654629031
# WBC_1 | Protein, total -0.07470194111981772
# WBC_1 | HGB -0.01407307860366016
# WBC_1 | RBC 0.05477427722226688
# WBC_1 | HCT 0.00109260711777002
# Osmolality (calc.) | WBC_1 -0.0018118272987655611
# Osmolality (calc.) | BASO (%) -0.1003621065279866
# Osmolality (calc.) | Sodium - REMOVE 0.7391806868252699
# Osmolality (calc.) | MCHC 0.026375804009291536
# Osmolality (calc.) | RDW 0.03164662311206309
# Osmolality (calc.) | Alkaline Phosphatase -0.017775730697677194
# Osmolality (calc.) | Bilirubin, total -0.064053985325424
# Osmolality (calc.) | Creatinine 0.35066522005025647
# Osmolality (calc.) | height 0.022905794527403163
# Osmolality (calc.) | Glucose 0.38915004573224155
# Osmolality (calc.) | PTT -0.009669429772237186
# Osmolality (calc.) | EOS (%) 0.02592052590126396
# Osmolality (calc.) | SGOT (AST) -0.00923935792285194
# Osmolality (calc.) | EOS (abs) 0.028904314824544725
# Osmolality (calc.) | blood pressure 0.029008678675850823
# Osmolality (calc.) | Urea - REMOVE 0.5703026565684146
# Osmolality (calc.) | PT -0.026631299953695065
# Osmolality (calc.) | heart rate -0.11633938612998866
# Osmolality (calc.) | INR 0.06523438438292034
# Osmolality (calc.) | NEUTRO (abs) 0.01022458556786416
# Osmolality (calc.) | body temperature -0.024757010060803896
# Osmolality (calc.) | Calcium, total 0.0036080187647739414
# Osmolality (calc.) | Chloride 0.4964232080246301
# Osmolality (calc.) | Phosphorus 0.04517964588371826
# Osmolality (calc.) | Bilirubin, direct -0.044557021193746535
# Osmolality (calc.) | Amylase 0.06189304062276048
# Osmolality (calc.) | Estimated Globulin -0.11194670404559592
# Osmolality (calc.) | NEUTRO (%) 0.06101677101573868
# Osmolality (calc.) | LYMPHO (%) -0.09196921652849323
# Osmolality (calc.) | Albumin -0.0884049666442647
# Osmolality (calc.) | weight  -0.031206910571803824
# Osmolality (calc.) | LYMPHO (abs) -0.09533565909682466
# Osmolality (calc.) | Protein, total -0.13360001403743738
# Osmolality (calc.) | HGB -0.06595320135560181
# Osmolality (calc.) | RBC -0.10620991168016458
# Osmolality (calc.) | HCT -0.07337541398953124
# BASO (abs) | Osmolality (calc.) -0.11302273673891498
# BASO (abs) | WBC_1 0.22353726125911316
# BASO (abs) | BASO (%) - REMOVE 0.8164948552880518
# BASO (abs) | Sodium -0.017506277694561097
# BASO (abs) | MCHC -0.03226554470210935
# BASO (abs) | RDW -0.10510715084247542
# BASO (abs) | Alkaline Phosphatase -0.04469873536838041
# BASO (abs) | Bilirubin, total -0.09367007436776914
# BASO (abs) | Creatinine -0.09526879891792438
# BASO (abs) | height -0.05291998179847795
# BASO (abs) | Glucose -0.0696015056827847
# BASO (abs) | PTT -0.0181022834610811
# BASO (abs) | EOS (%) 0.1328878134415269
# BASO (abs) | SGOT (AST) -0.016807011374610575
# BASO (abs) | EOS (abs) 0.24320351537682727
# BASO (abs) | blood pressure 0.14583349141616403
# BASO (abs) | Urea -0.16047666537508082
# BASO (abs) | PT 0.11800994632158632
# BASO (abs) | heart rate 0.007927370848896144
# BASO (abs) | INR -0.11062591505950467
# BASO (abs) | NEUTRO (abs) 0.09089905983721562
# BASO (abs) | body temperature 0.041230570740333074
# BASO (abs) | Calcium, total 0.1983561659057913
# BASO (abs) | Chloride -0.0461745931145097
# BASO (abs) | Phosphorus -0.0008909845237332903
# BASO (abs) | Bilirubin, direct -0.058544230372383
# BASO (abs) | Amylase -0.06329369934466822
# BASO (abs) | Estimated Globulin 0.2416321080189981
# BASO (abs) | NEUTRO (%) -0.16991992620918392
# BASO (abs) | LYMPHO (%) 0.1782318538565702
# BASO (abs) | Albumin 0.18713524496075257
# BASO (abs) | weight  0.0844241009514296
# BASO (abs) | LYMPHO (abs) 0.4209639772816349
# BASO (abs) | Protein, total 0.26739454398390056
# BASO (abs) | HGB 0.13313430680796498
# BASO (abs) | RBC 0.1486320553035296
# BASO (abs) | HCT 0.14072875269160362
# PCT | BASO (abs) 0.24132924065620162
# PCT | Osmolality (calc.) -0.0743125253354911
# PCT | WBC_1 0.41519268240324964
# PCT | BASO (%) 0.04999427406860354
# PCT | Sodium -0.08186231480234014
# PCT | MCHC -0.37922065797850624
# PCT | RDW 0.18902168319099977
# PCT | Alkaline Phosphatase -0.0029060747411770935
# PCT | Bilirubin, total -0.16842910130417227
# PCT | Creatinine -0.052980548158335125
# PCT | height -0.04843264323663205
# PCT | Glucose 0.04137315540633407
# PCT | PTT -0.15386553240527245
# PCT | EOS (%) 0.045471065297742516
# PCT | SGOT (AST) -0.02757637099692124
# PCT | EOS (abs) 0.17701811461369166
# PCT | blood pressure 0.020691654149731183
# PCT | Urea -0.029898717029738023
# PCT | PT 0.023299758492857512
# PCT | heart rate 0.19780853544017113
# PCT | INR -0.0413522204561553
# PCT | NEUTRO (abs) 0.35084287082876864
# PCT | body temperature 0.06129459290487745
# PCT | Calcium, total 0.003908737654297018
# PCT | Chloride -0.12994908427926813
# PCT | Phosphorus 0.0852228862699836
# PCT | Bilirubin, direct -0.11845426125681124
# PCT | Amylase -0.10576170446999872
# Potassium | Calcium, total 0.13926969109943965
# Potassium | Chloride -0.05098444799755962
# Potassium | Phosphorus 0.18977210313986798
# Potassium | Bilirubin, direct 0.030708205550983553
# Potassium | Amylase 0.10692000117475624
# Potassium | Estimated Globulin 0.12546786840247634
# Potassium | NEUTRO (%) -0.006084195193181017
# Potassium | LYMPHO (%) -0.005449593958512702
# Potassium | Albumin 0.04057015099386688
# Potassium | weight  0.02692457397945546
# Potassium | LYMPHO (abs) -0.003457345708584532
# Potassium | Protein, total 0.09969234252113122
# Potassium | HGB 0.046271734029964755
# Potassium | RBC 0.06358325931214719
# Potassium | HCT 0.06386565373935388
# MONO (abs) | Potassium -0.022960738833224675
# MONO (abs) | MPV 0.04942798753307537
# MONO (abs) | PCT 0.2876720353787639
# MONO (abs) | BASO (abs) 0.12010395820517637
# MONO (abs) | Osmolality (calc.) 0.024987218075959473
# MONO (abs) | WBC_1 - REMOVE 0.6171697160538389
# MONO (abs) | BASO (%) -0.10409891772725344
# MONO (abs) | Sodium -0.09920849914733125
# MONO (abs) | MCHC -0.08536635218307098
# MONO (abs) | RDW 0.014096920303310164
# MONO (abs) | Alkaline Phosphatase 0.0017234408065678435
# MONO (abs) | Bilirubin, total 0.06516284437630554
# MONO (abs) | Creatinine 0.15661917768079295
# MONO (abs) | height -0.0020352730737980343
# MONO (abs) | Glucose 0.18411166985487182
# MONO (abs) | PTT -0.06275772169817218
# MONO (abs) | EOS (%) -0.07128340741135494
# MONO (abs) | SGOT (AST) 0.06333468037802432
# MONO (abs) | EOS (abs) 0.1167222296677563
# MONO (abs) | blood pressure 0.12207647609432459
# MONO (abs) | Urea 0.10457516408041792
# MONO (abs) | PT -0.12267097809175764
# MONO (abs) | heart rate 0.12205465100841545
# MONO (abs) | INR 0.10945989951972078
# MONO (abs) | NEUTRO (abs) - REMOVE 0.5265589051011816
# MONO (abs) | body temperature 0.0215001044350629
# MONO (abs) | Calcium, total -0.0646964249279541
# MONO (abs) | Chloride -0.2038001274567937
# MONO (abs) | Phosphorus 0.0012468124476199514
# MONO (abs) | Bilirubin, direct 0.0705544135128196
# MONO (abs) | Amylase -0.06782970377705333
# MONO (abs) | Estimated Globulin 0.09050725444167824
# MONO (abs) | NEUTRO (%) 0.09277227646962556
# MONO (abs) | LYMPHO (%) -0.21375160614337474
# MONO (abs) | Albumin -0.1393518968484228
# MONO (abs) | weight  0.03752549675066098
# MONO (abs) | LYMPHO (abs) 0.18394354450736683
# MONO (abs) | Protein, total -0.061227132010612854
# MONO (abs) | HGB 0.018626703738546174
# MONO (abs) | RBC 0.06430907998864428
# MONO (abs) | HCT 0.03292329019552086
# PLT | MONO (abs) 0.26703588198739114
# PLT | Potassium 0.09442903496192334
# PLT | MPV -0.3399814520150708
# PLT | PCT - REMOVE 0.921964916736407
# PLT | BASO (abs) 0.1810780851917166
# PLT | Osmolality (calc.) -0.11509576119368961
# PLT | WBC_1 0.37254354877035223
# PLT | BASO (%) 0.020718421464800317
# PLT | Sodium -0.11937007841484301
# PLT | MCHC -0.3183778098212289
# PLT | RDW 0.20994431833827829
# PLT | Alkaline Phosphatase 0.002416494039997004
# PLT | Bilirubin, total -0.1519907303275851
# PLT | Creatinine -0.020312690735074558
# PLT | height -0.01972964687382462
# PLT | Glucose 0.016670625647972604
# PLT | PTT -0.1397413404285415
# PLT | EOS (%) 0.02565241790614132
# PLT | SGOT (AST) -0.043154163319082436
# PLT | EOS (abs) 0.12216265665623856
# PLT | blood pressure -0.007394525342897033
# PLT | Urea -0.02917982106642234
# PLT | PT -0.011618169516623408
# PLT | heart rate 0.20994917077595612
# PLT | INR -0.014557296659403049
# PLT | NEUTRO (abs) 0.33256563162119623
# PLT | body temperature 0.06728336870467126
# PLT | Calcium, total -0.06747965754476525
# PLT | Chloride -0.14081031642491112
# PLT | Phosphorus 0.06429485482604158
# PLT | Bilirubin, direct -0.10512715036411578
# PLT | Amylase -0.10454740610012937
# PLT | Estimated Globulin 0.22394258515351967
# PLT | NEUTRO (%) 0.14433498935769443
# PLT | LYMPHO (%) -0.1304694961921909
# PLT | Albumin -0.17676179988417262
# PLT | weight  -0.00019525944779684445
# PLT | LYMPHO (abs) 0.12574927910424438
# PLT | Protein, total -0.01460590905913025
# PLT | HGB -0.24600410432674652
# PLT | RBC -0.07603833965659326
# PLT | HCT -0.21298243716886556
# MONO (%) | PLT -0.12065609949895889
# MONO (%) | MONO (abs) 0.4378784060546649
# MONO (%) | Potassium -0.015712799488682806
# MONO (%) | MPV -0.08310454025094459
# MONO (%) | PCT -0.17632324758129964
# MONO (%) | BASO (abs) -0.11166408417710288
# MONO (%) | Osmolality (calc.) 0.08195963008730606
# MONO (%) | WBC_1 -0.31461673714157445
# MONO (%) | BASO (%) 0.10909236830053752
# MONO (%) | Sodium 0.05575394810768271
# MONO (%) | MCHC 0.06739659282469637
# MONO (%) | RDW 0.09818563992404787
# MONO (%) | Alkaline Phosphatase 0.08492072212909954
# MONO (%) | Bilirubin, total 0.1329571292730054
# MONO (%) | Creatinine 0.12229042326367211
# MONO (%) | height 0.07870114327495178
# MONO (%) | Glucose 0.0011997978436870463
# MONO (%) | PTT -0.0037346411578785352
# MONO (%) | EOS (%) 0.07719737764524133
# MONO (%) | SGOT (AST) 0.07714558852384253
# MONO (%) | EOS (abs) -0.01766679063186409
# MONO (%) | blood pressure -0.043907073358493226
# MONO (%) | Urea 0.07849860078891088
# MONO (%) | PT -0.09526354009655491
# MONO (%) | heart rate -0.056217024466524115
# MONO (%) | INR 0.12732852744717676
# MONO (%) | NEUTRO (abs) -0.34340393437482
# MONO (%) | body temperature 0.045093949619290176
# MONO (%) | Calcium, total -0.06000815539280934
# MONO (%) | Chloride 0.008625984207957654
# MONO (%) | Phosphorus -0.039517346613496096
# MONO (%) | Bilirubin, direct 0.17927759196913093
# MONO (%) | Amylase -0.05075312913942892
# MONO (%) | Estimated Globulin -0.05952109904627194
# MONO (%) | NEUTRO (%) -0.3400622535660469
# MONO (%) | LYMPHO (%) 0.08212194300680697
# MONO (%) | Albumin -0.11300327235248273
# MONO (%) | weight  -0.08206244317946448
# MONO (%) | LYMPHO (abs) -0.1529659535706265
# MONO (%) | Protein, total -0.11752094653039849
# MONO (%) | HGB -0.08418910975047866
# MONO (%) | RBC -0.11312538540628801
# MONO (%) | HCT -0.09508919570965145
# Gamma-GT | MONO (%) 0.21990284841841848
# Gamma-GT | PLT -0.050977049186223304
# Gamma-GT | MONO (abs) 0.06220038830497182
# Gamma-GT | Potassium 0.06496695938643704
# Gamma-GT | MPV 0.04089135655053336
# Gamma-GT | PCT -0.06176438618755927
# Gamma-GT | BASO (abs) -0.02999609602920898
# Gamma-GT | Osmolality (calc.) -0.0001129669838812325
# Gamma-GT | WBC_1 -0.0468764379387888
# Gamma-GT | BASO (%) 0.07188129295553702
# Gamma-GT | Sodium -0.07509704328253443
# Gamma-GT | MCHC 0.10041234714256246
# Gamma-GT | RDW 0.0750461769783308
# Gamma-GT | Alkaline Phosphatase - REMOVE 0.7450197836949631
# Gamma-GT | Bilirubin, total - REMOVE 0.687521087343664
# Gamma-GT | Creatinine 0.03361960364075427
# Gamma-GT | height -0.010455295366682354
# Gamma-GT | Glucose 0.09406215964058347
# Gamma-GT | PTT 0.030473773024096932
# Gamma-GT | EOS (%) -0.008639678295417508
# Gamma-GT | SGOT (AST) - REMOVE 0.6437197738476796
# Gamma-GT | EOS (abs) -0.025399583787810303
# Gamma-GT | blood pressure -0.06158899288416671
# Gamma-GT | Urea 0.06761032573024116
# Gamma-GT | PT -0.08737008597838805
# Gamma-GT | heart rate 0.0651344337808788
# Gamma-GT | INR 0.12141617443969792
# Gamma-GT | NEUTRO (abs) -0.030085260120841048
# Gamma-GT | body temperature 0.012573407377929217
# Gamma-GT | Calcium, total -0.15057686506575824
# Gamma-GT | Chloride -0.06379200495203428
# Gamma-GT | Phosphorus -0.08812669808710029
# Gamma-GT | Bilirubin, direct - REMOVE 0.7700297325638643
# Gamma-GT | Amylase 0.06173808022284376
# Gamma-GT | Estimated Globulin -0.08919846579738026

# %%
plot_1row (dj_before_surgery, 'disjointification - before surgery', 'regular')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-346-e64516c64a0f> in <module>
# ----> 1 plot_1row (dj_before_surgery, 'disjointification - before surgery', 'regular')
#
# <ipython-input-251-50909df3a80c> in plot_1row(df, title, type)
#       5         ax = sns.barplot(-np.log(df.values.reshape(-1,).tolist()), df.columns)
#       6     else:
# ----> 7         ax = sns.barplot((df.values.reshape(-1,).tolist()), df.columns)
#       8     ax.set_title(title, size=20)
#       9     for p in ax.patches:
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
plot_1row (dj_after_surgery, 'disjointification - after surgery', 'regular')

# %%
plot_1row (dj_delta, 'disjointification - delta', 'regular')

# %% [markdown]
# #### FDR
# Apply false discovery rate
#
# https://matthew-brett.github.io/teaching/fdr.html

# %%
def get_fdr_plot (df ,title):
    
    p_values = np.sort(df)
    q = 0.05
    N = p_values.size
    i = np.arange(1,N+1) # the 1-based i index of the p values, as in p(i)
    
    plt.figure(figsize=(10,5))
    
    plt.title(title)
    plt.plot(i, p_values,  'b.', label='$p(i)$')
    plt.plot(i, q * i / N, 'r', label='$q i / N$') # the acceptable number of false positives
    plt.xlabel('$i$')
    plt.ylabel('p value')
    plt.legend()
    plt.show()
    return

# %% [markdown]
# We are looking for the largest $p(i) < q*i/N$, which corresponds to the last blue point below the red line

# %%
get_fdr_plot(stats_before_surgery_data.iloc[0,:], 'FDR for before surgery data')

# %%
get_fdr_plot(stats_after_surgery_data.iloc[0,:], 'FDR for after surgery data')

# %%
get_fdr_plot(stats_surgery_data_delta.iloc[0,:], 'FDR for delta data')

# %% [markdown]
# FDR Fix

# %%
# import statsmodels
# from statsmodels.sandbox.stats.multicomp import fdrcorrection0
# ss.multitest.fdrcorrection(stats_before_surgery_data.iloc[0,:].values, alpha=0.05, method='indep', is_sorted=False)

# %% [markdown]
# #### 1.1.3. Boxplots for Significant Features

# %%
def significant_features(df,title):
#     plt.figure(figsize=(15,10))
    sns.boxplot(x=df.columns[0], y=df.columns[1], data=df)
    sns.swarmplot(x=df.columns[0], y=df.columns[1], data=df, color=".25")
    plt.title(title)
    plt.show()

# %%
print("Patient Data")
significant_features(patient_data[['Anastomotic Leak', 'Age']],"Age")
# Out:
# Patient Data

# %%
# before_surgery_data[before_surgery_data['BMI']> 60]

# %%
print('Before Surgery')
sigfig_before = ['Albumin', 'BMI', 'HGB', 'HCT', 'LYMPHO (%)', 'RBC', 'Protein, total', 'weight ']
for i in sigfig_before:
    significant_features(before_surgery_data[['Anastomotic Leak', i]],i)
# Out:
# Before Surgery

# %%
before_surgery_data.columns
# Out:
# Index(['Anastomotic Leak', 'Albumin', 'Alkaline Phosphatase', 'Amylase',
#        'BASO (%)', 'BASO (abs)', 'BMI', 'Bilirubin, direct',
#        'Bilirubin, total', 'Calcium, total', 'Chloride', 'Creatinine',
#        'EOS (%)', 'EOS (abs)', 'Estimated Globulin', 'Gamma-GT', 'Glucose',
#        'HCT', 'HGB', 'INR', 'LYMPHO (%)', 'LYMPHO (abs)', 'MCH', 'MCHC', 'MCV',
#        'MONO (%)', 'MONO (abs)', 'MPV', 'Magnesium', 'NEUTRO (abs)',
#        'NEUTRO (%)', 'Nucleated RBC (%)', 'Nucleated RBC (abs)',
#        'Osmolality (calc.)', 'PCT', 'PLT', 'PT', 'PTT', 'Phosphorus',
#        'Potassium', 'Protein, total', 'RBC', 'RDW', 'SGOT (AST)', 'SGPT (ALT)',
#        'Sodium', 'Urea', 'WBC_1', 'blood pressure', 'body temperature',
#        'heart rate', 'height', 'saturation', 'weight '],
#       dtype='object')

# %%
sigfig_before
# Out:
# ['Albumin',
#  'BMI',
#  'HGB',
#  'HCT',
#  'LYMPHO (%)',
#  'RBC',
#  'Protein, total',
#  'weight ']

# %% [markdown]
# ### 1.2.
# #### Removing partient that have no events AND target is without AL

# %%
# patient_with_enough_events = full_df.dropna(axis = 0, how = all ,thresh=300)
# patient_with_enough_events.isnull().sum(axis=1)

# RESULT_PATH = 'patient_with_enough_events.xlsx'
# patient_missing_events.to_excel(RESULT_PATH)
