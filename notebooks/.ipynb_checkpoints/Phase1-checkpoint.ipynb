# %% [markdown]
# # Anastomotic Leakage Prediction
# ### Phase 1

# %% [markdown]
# Taking the existing data manipulation and investigating:
# #### 1.1.
# * WRS, p value on the leakage vs not leakage for each existing attributes
# * Drop patients with missing value for the specific attribute in wrs
#
# #### 1.2.
# * If patients have no event data and have 0 on target, remove them
#
# #### 1.3.
# * Add categorical data and anlysize correlation to target via hypergeometric
#
# #### 1.4.
# * Clear data by outlier detection. Look at the stf if its past 3std from teh mean on both sides

# %%
import pandas as pd
import numpy as np
import re
import math
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline  
from datetime import datetime
from datetime import date 
from scipy import stats

import warnings
warnings.filterwarnings("ignore")

# %%
COMBINED_DATA_FILE = '../data_files/matrix0_missing_values.xlsx'
EVENTS = '../data_files/data1.csv'
PATIENTS = '../data_files/anonymous_080620_DA_eg.xlsx'

full_df = pd.read_excel(COMBINED_DATA_FILE, header=[0,1,2,3])[1:]
events_df = pd.read_csv(EVENTS)
patients_df = pd.read_excel(PATIENTS)

# %%
full_df
# Out:
#            type metadata                                       \
#            time  general
#         feature      Sex      Age   Urgency Surgical approach
#       statistic constant constant  constant          constant
# 1       1123813     male     59.0  elective              Open
# 2       1135541   female     43.0  elective              Open
# 3       3918745   female     57.0  elective      Laparoscopic
# 4       4894647      NaN      NaN  elective              Open
# 5       6541482   female     65.0    urgent              Open
# ..          ...      ...      ...       ...               ...
# 521  1031926105   female     63.0  elective              Open
# 522  1032366104   female     63.0  elective              Open
# 523  1033842103     male     61.0  elective              Open
# 524  1034462102     male     76.0  elective              Open
# 525  1035830101   female     65.0  elective              Open
#
#                      numeric_events                        ...                \
#                      before_surgery                        ... after_surgery
#     Anastomotic Leak        Albumin                        ...       weight
#             constant            max      mean median  min  ...          mean
# 1                1.0            4.2  4.200000   4.20  4.2  ...     96.966667
# 2                0.0            NaN       NaN    NaN  NaN  ...     68.000000
# 3                0.0            3.9  3.900000   3.90  3.9  ...           NaN
# 4                0.0            4.3  4.300000   4.30  4.3  ...     71.125000
# 5                0.0            3.1  1.942857   1.95  1.4  ...     54.666667
# ..               ...            ...       ...    ...  ...  ...           ...
# 521              0.0            NaN       NaN    NaN  NaN  ...           NaN
# 522              0.0            4.1  4.100000   4.10  4.1  ...     50.500000
# 523              1.0            4.8  4.800000   4.80  4.8  ...           NaN
# 524              0.0            4.3  4.300000   4.30  4.3  ...           NaN
# 525              0.0            3.7  3.700000   3.70  3.7  ...           NaN
#
#                      drugs                                     \
#                   all_days
#                  Cefazolin Ceftriaxone Fleet enema Furosemide
#     median   min     count       count       count      count
# 1    105.0  85.3       6.0        13.0         1.0       16.0
# 2     68.0  68.0       NaN        10.0         NaN        2.0
# 3      NaN   NaN       NaN         NaN         NaN        NaN
# 4     74.6   0.0       5.0        12.0         1.0       38.0
# 5     53.0  53.0       4.0        15.0         NaN      151.0
# ..     ...   ...       ...         ...         ...        ...
# 521    NaN   NaN       2.0         NaN         1.0        NaN
# 522   52.0  46.0       3.0         1.0         2.0        2.0
# 523    NaN   NaN       4.0        27.0         1.0        8.0
# 524    NaN   NaN       5.0         NaN         1.0        NaN
# 525    NaN   NaN       1.0         NaN         1.0        NaN
#
#
#
#     Magnesium sulfate Meroken new Metronidazole
#                 count       count         count
# 1                 4.0         1.0          52.0
# 2                 NaN         NaN          26.0
# 3                 NaN         NaN           NaN
# 4                 1.0         1.0          73.0
# 5                 7.0         NaN          51.0
# ..                ...         ...           ...
# 521               NaN         1.0           2.0
# 522              24.0         2.0           4.0
# 523              13.0         1.0          62.0
# 524               2.0         1.0           3.0
# 525               1.0         1.0           1.0
#
# [525 rows x 481 columns]

# %% [markdown]
# ### 1.1
# #### WRS Statistical Significance
# We will restructure the data to hold one feature value from the large header and the mean value from all event data.
# We will skip NaN values

# %%
group_one = full_df.iloc[:, 1:6]
group_one.columns = full_df.columns.get_level_values(2)[1:6]

# %%
group_one
# Out:
#         Sex   Age   Urgency Surgical approach  Anastomotic Leak
# 1      male  59.0  elective              Open               1.0
# 2    female  43.0  elective              Open               0.0
# 3    female  57.0  elective      Laparoscopic               0.0
# 4       NaN   NaN  elective              Open               0.0
# 5    female  65.0    urgent              Open               0.0
# ..      ...   ...       ...               ...               ...
# 521  female  63.0  elective              Open               0.0
# 522  female  63.0  elective              Open               0.0
# 523    male  61.0  elective              Open               1.0
# 524    male  76.0  elective              Open               0.0
# 525  female  65.0  elective              Open               0.0
#
# [525 rows x 5 columns]

# %%
group_two = full_df.iloc[:,6:-7]

# %%
# 4 = Taking the mean from each features
group_two = group_two.iloc[:, 1::4]
group_two.columns = group_two.columns.get_level_values(2)

# %%
group_two.shape
# Out:
# (525, 117)

# %%
group_two
# Out:
#       Albumin  Alkaline Phosphatase    Amylase  BASO (%)  BASO (abs)   BMI  \
# 1    4.200000                  97.0  63.000000  0.500000    0.030000  35.3
# 2         NaN                   NaN        NaN       NaN         NaN   NaN
# 3    3.900000                  90.0  53.000000  0.400000    0.040000  38.8
# 4    4.300000                  70.0        NaN  0.300000    0.030000   NaN
# 5    1.942857                  94.0  32.692308  0.121429    0.015714  23.6
# ..        ...                   ...        ...       ...         ...   ...
# 521       NaN                   NaN        NaN       NaN         NaN  30.8
# 522  4.100000                 133.0  78.000000  0.600000    0.030000   NaN
# 523  4.800000                  89.0  19.000000  0.300000    0.020000  24.7
# 524  4.300000                  92.0  95.000000  0.500000    0.030000  26.6
# 525  3.700000                 101.0  40.000000  0.400000    0.030000  24.4
#
#      Bilirubin, direct  Bilirubin, total  Calcium, total    Chloride  ...  \
# 1                 0.22          1.500000        9.900000  105.000000  ...
# 2                  NaN               NaN             NaN         NaN  ...
# 3                 0.06          0.370000        9.800000  102.000000  ...
# 4                  NaN          0.360000        9.700000  101.000000  ...
# 5                 0.18          0.586429        7.428571  100.142857  ...
# ..                 ...               ...             ...         ...  ...
# 521                NaN               NaN             NaN         NaN  ...
# 522               0.05          0.260000        9.300000  107.000000  ...
# 523               0.21          1.030000        9.600000  107.000000  ...
# 524               0.08          0.420000        9.200000  104.000000  ...
# 525               0.07          0.480000        9.100000  105.000000  ...
#
#          WBC_1  blood pressure  blood pressure diastolic   \
# 1     7.262093       89.676093                  64.431373
# 2    11.480556       90.180000                  51.000000
# 3    11.616000      115.000000                  75.357143
# 4     5.549455       89.430524                  63.564885
# 5    13.174151       99.845560                  76.267176
# ..         ...             ...                        ...
# 521   5.947778      106.214286                  67.270588
# 522   4.561719      102.408163                  64.205357
# 523   9.365849       98.692230                  71.186441
# 524   5.274000      121.948276                  58.076923
# 525   9.785455       94.272727                  64.230769
#
#      blood pressure systolic  body temperature  heart rate      height  \
# 1                 120.596026         36.609656   87.566667  174.000000
# 2                  97.000000         36.745455   87.760000  170.000000
# 3                 126.851852         35.727778   73.147059         NaN
# 4                 114.832000         36.658712   86.694690  168.583333
# 5                 128.078740         36.910182   89.780980  150.000000
# ..                       ...               ...         ...         ...
# 521               121.282353         36.652381  100.649254         NaN
# 522               119.700000         36.592308   87.720548  151.285714
# 523               129.844828         37.121285   87.518519         NaN
# 524               118.947368         36.175000   74.742424         NaN
# 525               110.555556         36.853333   93.605839         NaN
#
#      respiratory rate, CO2  saturation    weight
# 1                 9.800000   97.169284  96.966667
# 2                 6.647059   97.927711  68.000000
# 3                 4.684211   96.787879        NaN
# 4                 6.585366   96.739583  71.125000
# 5                 8.125000   97.231970  54.666667
# ..                     ...         ...        ...
# 521               9.593750   97.245455        NaN
# 522               5.288136   97.741935  50.500000
# 523              11.107143   96.892694        NaN
# 524              11.916667   97.530303        NaN
# 525               8.758621   97.781818        NaN
#
# [525 rows x 117 columns]

# %%
wrs_data = pd.concat([group_one, group_two], axis=1, sort=False)

# %%
wrs_data
# Out:
#         Sex   Age   Urgency Surgical approach  Anastomotic Leak   Albumin  \
# 1      male  59.0  elective              Open               1.0  4.200000
# 2    female  43.0  elective              Open               0.0       NaN
# 3    female  57.0  elective      Laparoscopic               0.0  3.900000
# 4       NaN   NaN  elective              Open               0.0  4.300000
# 5    female  65.0    urgent              Open               0.0  1.942857
# ..      ...   ...       ...               ...               ...       ...
# 521  female  63.0  elective              Open               0.0       NaN
# 522  female  63.0  elective              Open               0.0  4.100000
# 523    male  61.0  elective              Open               1.0  4.800000
# 524    male  76.0  elective              Open               0.0  4.300000
# 525  female  65.0  elective              Open               0.0  3.700000
#
#      Alkaline Phosphatase    Amylase  BASO (%)  BASO (abs)  ...      WBC_1  \
# 1                    97.0  63.000000  0.500000    0.030000  ...   7.262093
# 2                     NaN        NaN       NaN         NaN  ...  11.480556
# 3                    90.0  53.000000  0.400000    0.040000  ...  11.616000
# 4                    70.0        NaN  0.300000    0.030000  ...   5.549455
# 5                    94.0  32.692308  0.121429    0.015714  ...  13.174151
# ..                    ...        ...       ...         ...  ...        ...
# 521                   NaN        NaN       NaN         NaN  ...   5.947778
# 522                 133.0  78.000000  0.600000    0.030000  ...   4.561719
# 523                  89.0  19.000000  0.300000    0.020000  ...   9.365849
# 524                  92.0  95.000000  0.500000    0.030000  ...   5.274000
# 525                 101.0  40.000000  0.400000    0.030000  ...   9.785455
#
#      blood pressure  blood pressure diastolic   blood pressure systolic  \
# 1         89.676093                  64.431373               120.596026
# 2         90.180000                  51.000000                97.000000
# 3        115.000000                  75.357143               126.851852
# 4         89.430524                  63.564885               114.832000
# 5         99.845560                  76.267176               128.078740
# ..              ...                        ...                      ...
# 521      106.214286                  67.270588               121.282353
# 522      102.408163                  64.205357               119.700000
# 523       98.692230                  71.186441               129.844828
# 524      121.948276                  58.076923               118.947368
# 525       94.272727                  64.230769               110.555556
#
#      body temperature  heart rate      height  respiratory rate, CO2  \
# 1           36.609656   87.566667  174.000000               9.800000
# 2           36.745455   87.760000  170.000000               6.647059
# 3           35.727778   73.147059         NaN               4.684211
# 4           36.658712   86.694690  168.583333               6.585366
# 5           36.910182   89.780980  150.000000               8.125000
# ..                ...         ...         ...                    ...
# 521         36.652381  100.649254         NaN               9.593750
# 522         36.592308   87.720548  151.285714               5.288136
# 523         37.121285   87.518519         NaN              11.107143
# 524         36.175000   74.742424         NaN              11.916667
# 525         36.853333   93.605839         NaN               8.758621
#
#      saturation    weight
# 1     97.169284  96.966667
# 2     97.927711  68.000000
# 3     96.787879        NaN
# 4     96.739583  71.125000
# 5     97.231970  54.666667
# ..          ...        ...
# 521   97.245455        NaN
# 522   97.741935  50.500000
# 523   96.892694        NaN
# 524   97.530303        NaN
# 525   97.781818        NaN
#
# [525 rows x 122 columns]

# %% [markdown]
# Now we will translate catagorical data to numerical values

# %%
sex_translator = {
    'female': 0,
    'male': 1
}

urgency_translator = {
    'elective': 0,
    'urgent': 1
}

surgical_approach_translator = {
    'Open': 0,
    'Laparoscopic': 1,
    'Robotic Surgery': 2
}

wrs_data['Sex'] = wrs_data['Sex'].replace(sex_translator)
wrs_data['Urgency'] = wrs_data['Urgency'].replace(urgency_translator)
wrs_data['Surgical approach'] = wrs_data['Surgical approach'].replace(surgical_approach_translator)

# %%
def calc_wrs(f):
#     print(f)
    ## defining the two independent samples
    a = f[wrs_data['Anastomotic Leak'] == 0.0].dropna()
    b = f[wrs_data['Anastomotic Leak'] == 1.0].dropna()
    return stats.ranksums(a,b)

wrs_calc_data = wrs_data.apply(calc_wrs, axis=0, result_type="expand")

# %% [markdown]
# ### The Wilcoxon Rank Sum results are the following:
# _For the target value:_
#
# 0: statistic - The test statistic under the large-sample approximation that the rank sum statistic is normally distributed.
#
# 1: pvalue - The two-sided p-value of the test.

# %%
wrs_calc_data
# Out:
#         Sex       Age   Urgency  Surgical approach  Anastomotic Leak  \
# 0 -1.290380 -2.707043 -1.153547           4.455240     -1.087240e+01
# 1  0.196919  0.006789  0.248686           0.000008      1.560378e-27
#
#     Albumin  Alkaline Phosphatase   Amylase  BASO (%)  BASO (abs)  ...  \
# 0  2.910859             -1.042191 -2.171204  0.864573    0.710674  ...
# 1  0.003604              0.297323  0.029916  0.387273    0.477286  ...
#
#       WBC_1  blood pressure  blood pressure diastolic   \
# 0 -2.911621        0.378379                  -0.156530
# 1  0.003596        0.705149                   0.875616
#
#    blood pressure systolic  body temperature  heart rate    height  \
# 0                 1.082072         -4.317991   -4.115627 -0.006677
# 1                 0.279220          0.000016    0.000039  0.994673
#
#    respiratory rate, CO2  saturation   weight
# 0              -0.352159    0.871642  3.108573
# 1               0.724719    0.383404  0.001880
#
# [2 rows x 122 columns]

# %%
print("Surgery and Patient Data") 
wrs_calc_data.iloc[:, 0:4]
# Out:
# Surgery and Patient Data
#         Sex       Age   Urgency  Surgical approach
# 0 -1.290380 -2.707043 -1.153547           4.455240
# 1  0.196919  0.006789  0.248686           0.000008

# %%
print("Before Surgery") 
wrs_calc_data.iloc[:, 5:58]
# Out:
# Before Surgery
#     Albumin  Alkaline Phosphatase   Amylase  BASO (%)  BASO (abs)       BMI  \
# 0  2.910859             -1.042191 -2.171204  0.864573    0.710674  3.583689
# 1  0.003604              0.297323  0.029916  0.387273    0.477286  0.000339
#
#    Bilirubin, direct  Bilirubin, total  Calcium, total  Chloride  ...  \
# 0          -2.042350         -1.083652        1.736398 -1.825577  ...
# 1           0.041117          0.278519        0.082493  0.067914  ...
#
#    SGPT (ALT)    Sodium      Urea     WBC_1  blood pressure  body temperature  \
# 0   -0.103775  0.875854 -1.503132 -0.826703        1.371157          1.628597
# 1    0.917348  0.381110  0.132805  0.408406        0.170326          0.103398
#
#    heart rate    height  saturation   weight
# 0   -1.542313 -1.276854    0.114627  3.068128
# 1    0.122998  0.201654    0.908741  0.002154
#
# [2 rows x 53 columns]

# %%
print("After Surgery") 
wrs_calc_data.iloc[:, 58:]
# Out:
# After Surgery
#         Albumin  Alkaline Phosphatase   Amylase  BASO (%)  BASO (abs)  \
# 0  7.056034e+00         -5.199324e+00 -1.009749  0.423469   -0.293957
# 1  1.713225e-12          2.000146e-07  0.312615  0.671953    0.768791
#
#         BMI  Bilirubin, direct  Bilirubin, total  Calcium, total  Chloride  \
# 0  3.841457          -1.906779          0.061801        4.156101  2.343055
# 1  0.000122           0.056549          0.950722        0.000032  0.019127
#
#    ...     WBC_1  blood pressure  blood pressure diastolic   \
# 0  ... -2.911621        0.378379                  -0.156530
# 1  ...  0.003596        0.705149                   0.875616
#
#    blood pressure systolic  body temperature  heart rate    height  \
# 0                 1.082072         -4.317991   -4.115627 -0.006677
# 1                 0.279220          0.000016    0.000039  0.994673
#
#    respiratory rate, CO2  saturation   weight
# 0              -0.352159    0.871642  3.108573
# 1               0.724719    0.383404  0.001880
#
# [2 rows x 64 columns]

# %% [markdown]
# ### 1.2.
# #### Removing partient that have no events AND target is without AL

# %%
full_df
# Out:
#            type metadata                                       \
#            time  general
#         feature      Sex      Age   Urgency Surgical approach
#       statistic constant constant  constant          constant
# 1       1123813     male     59.0  elective              Open
# 2       1135541   female     43.0  elective              Open
# 3       3918745   female     57.0  elective      Laparoscopic
# 4       4894647      NaN      NaN  elective              Open
# 5       6541482   female     65.0    urgent              Open
# ..          ...      ...      ...       ...               ...
# 521  1031926105   female     63.0  elective              Open
# 522  1032366104   female     63.0  elective              Open
# 523  1033842103     male     61.0  elective              Open
# 524  1034462102     male     76.0  elective              Open
# 525  1035830101   female     65.0  elective              Open
#
#                      numeric_events                        ...                \
#                      before_surgery                        ... after_surgery
#     Anastomotic Leak        Albumin                        ...       weight
#             constant            max      mean median  min  ...          mean
# 1                1.0            4.2  4.200000   4.20  4.2  ...     96.966667
# 2                0.0            NaN       NaN    NaN  NaN  ...     68.000000
# 3                0.0            3.9  3.900000   3.90  3.9  ...           NaN
# 4                0.0            4.3  4.300000   4.30  4.3  ...     71.125000
# 5                0.0            3.1  1.942857   1.95  1.4  ...     54.666667
# ..               ...            ...       ...    ...  ...  ...           ...
# 521              0.0            NaN       NaN    NaN  NaN  ...           NaN
# 522              0.0            4.1  4.100000   4.10  4.1  ...     50.500000
# 523              1.0            4.8  4.800000   4.80  4.8  ...           NaN
# 524              0.0            4.3  4.300000   4.30  4.3  ...           NaN
# 525              0.0            3.7  3.700000   3.70  3.7  ...           NaN
#
#                      drugs                                     \
#                   all_days
#                  Cefazolin Ceftriaxone Fleet enema Furosemide
#     median   min     count       count       count      count
# 1    105.0  85.3       6.0        13.0         1.0       16.0
# 2     68.0  68.0       NaN        10.0         NaN        2.0
# 3      NaN   NaN       NaN         NaN         NaN        NaN
# 4     74.6   0.0       5.0        12.0         1.0       38.0
# 5     53.0  53.0       4.0        15.0         NaN      151.0
# ..     ...   ...       ...         ...         ...        ...
# 521    NaN   NaN       2.0         NaN         1.0        NaN
# 522   52.0  46.0       3.0         1.0         2.0        2.0
# 523    NaN   NaN       4.0        27.0         1.0        8.0
# 524    NaN   NaN       5.0         NaN         1.0        NaN
# 525    NaN   NaN       1.0         NaN         1.0        NaN
#
#
#
#     Magnesium sulfate Meroken new Metronidazole
#                 count       count         count
# 1                 4.0         1.0          52.0
# 2                 NaN         NaN          26.0
# 3                 NaN         NaN           NaN
# 4                 1.0         1.0          73.0
# 5                 7.0         NaN          51.0
# ..                ...         ...           ...
# 521               NaN         1.0           2.0
# 522              24.0         2.0           4.0
# 523              13.0         1.0          62.0
# 524               2.0         1.0           3.0
# 525               1.0         1.0           1.0
#
# [525 rows x 481 columns]

# %%
full_df.isnull().sum(axis=1)
# Out:
# 1        0
# 2      216
# 3       27
# 4       26
# 5        2
#       ...
# 521    199
# 522      4
# 523      8
# 524     14
# 525     14
# Length: 525, dtype: int64

# %%
patient_missing_events = full_df.dropna(axis = 0, how = all ,thresh=((full_df.shape[1]-6)*0.60))

# %%
patient_missing_events.isnull().sum(axis=1)
# Out:
# 1       0
# 3      27
# 4      26
# 5       2
# 7       4
#        ..
# 520    11
# 522     4
# 523     8
# 524    14
# 525    14
# Length: 353, dtype: int64

# %%
(full_df.shape[1]-6)*0.60 / 4
# Out:
# 71.25

# %%
RESULT_PATH = 'patient_with_71_missing_events.xlsx'
patient_missing_events.to_excel(RESULT_PATH)
